# %%
HUME_API_KEY=""

# %%
VIDEO_URL = "https://www.youtube.com/shorts/sXnTNcXh89g?feature=share"
HUME_API_KEY =HUME_API_KEY

video_file = download_video(VIDEO_URL)

analyzer = HumeEmotionAnalyzer(HUME_API_KEY)

results = await analyzer.analyze_video(video_file)

print(json.dumps(results, indent=2))

# %%
import yt_dlp

url = "https://www.youtube.com/shorts/YvGsM2_q7PE?feature=share"

with yt_dlp.YoutubeDL({
    "format": "best",
    "outtmpl": "video.mp4"
}) as ydl:
    ydl.download([url])

# %%
import cv2

cap = cv2.VideoCapture("video.mp4")

success, frame = cap.read()

if success:
    cv2.imwrite("frame.jpg", frame)

cap.release()

# %%
from azure.ai.vision.imageanalysis import ImageAnalysisClient
from azure.ai.vision.imageanalysis.models import VisualFeatures
from azure.core.credentials import AzureKeyCredential

endpoint = ""
key = ""

client = ImageAnalysisClient(
    endpoint=endpoint,
    credential=AzureKeyCredential(key)
)

with open("frame.jpg", "rb") as f:

    result = client.analyze(
        image_data=f.read(),
        visual_features=[
            VisualFeatures.PEOPLE
        ]
    )

print(result)
# Out:
# {'modelVersion': '2023-10-01', 'metadata': {'width': 360, 'height': 640}, 'peopleResult': {'values': [{'boundingBox': {'x': 30, 'y': 71, 'w': 322, 'h': 568}, 'confidence': 0.8091994524002075}, {'boundingBox': {'x': 75, 'y': 348, 'w': 221, 'h': 291}, 'confidence': 0.07481969147920609}, {'boundingBox': {'x': 62, 'y': 266, 'w': 271, 'h': 172}, 'confidence': 0.003911633975803852}]}}

# %%
from moviepy import VideoFileClip

video = VideoFileClip("video.mp4")
video.audio.write_audiofile("audio.wav")

print("Audio Extracted")
# Out:
# MoviePy - Writing audio in audio.wav
# MoviePy - Done.
# Audio Extracted
